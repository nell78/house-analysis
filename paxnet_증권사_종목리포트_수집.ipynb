# %% [markdown]
# <a href="https://colab.research.google.com/github/nell78/house-analysis/blob/main/paxnet_%EC%A6%9D%EA%B6%8C%EC%82%AC_%EC%A2%85%EB%AA%A9%EB%A6%AC%ED%8F%AC%ED%8A%B8_%EC%88%98%EC%A7%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # html request로 받아오기

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.paxnet.co.kr/stock/report/report?wlog_rpt=jm&menuCode=2222'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- 코드리스트 타임스탬프s -->
# <!-- 코드리스트 타임스탬프e --></head><body><p>
# </p><title> 종목리포트 | 증권사리포트 | 투자전략 - 팍스넷 증권포털</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content='CP="CAO DSP AND SO " policyref="/w3c/p3p.xml"' http-equiv="p3p"/>
# <meta content="//image.paxnet.co.kr/rpan/common/images/ogimage.png" property="og:image"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, target-densityDpi=medium-dpi" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <link href="//image.paxnet.co.kr/rpan/common/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//image.paxnet.co.kr/rpan/common/images/launcher_180.png" rel="apple-touch-icon"/>
# ...

# %% [markdown]
# # bs4로 파싱
# - 전체 표: `<div class="board-type">`
# - 리스트 아이템: `<li>`

# %%
# 전체 표
table = soup.find('div', {'class': 'board-type'})

# %%
# 리스트 아이템
list_items = table.find_all('li')

# %%
# 리스트 아이템의 첫번째 값: 컬럼명
list_items[0]
# Out:
# <li class="board-list-th">
# <div>종목</div>
# <div>제목</div>
# <div class="right">적정가격</div>
# <div>투자의견</div>
# <div>제공출처</div>
# <div class="cent">작성일</div>
# </li>

# %%
# 리스트 아이템의 두번째 값
list_items[1]
# Out:
# <li>
# <div><strong class="color-cate"><span class="bracket">[</span><a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=049070">인탑스</a><span class="bracket">]</span></strong></div>
# <div>
# <p>
# <a href="javascript:selectView('145956');">로봇 EMS 기대감</a>
# </p>
# </div>
# <div class="line3">
# <span>적정가격</span>
#
#
# 											30,000원
#
#
#
# 								</div>
# <div class="line3 color-red">
# 									매수
# 								</div>
# <div class="line3">LS증권</div>
# <div class="line3">2024.10.28</div>
# </li>

# %%
# 리스트 아이템의 마지막 값
list_items[-5]
# Out:
# <li class="on"><a href="#">1</a></li>

# %%
list_items[1]
# Out:
# <li>
# <div><strong class="color-cate"><span class="bracket">[</span><a href="http://www.paxnet.co.kr/stock/analysis/main?wlog_rpt=list_jm&amp;abbrSymbol=049070">인탑스</a><span class="bracket">]</span></strong></div>
# <div>
# <p>
# <a href="javascript:selectView('145956');">로봇 EMS 기대감</a>
# </p>
# </div>
# <div class="line3">
# <span>적정가격</span>
#
#
# 											30,000원
#
#
#
# 								</div>
# <div class="line3 color-red">
# 									매수
# 								</div>
# <div class="line3">LS증권</div>
# <div class="line3">2024.10.28</div>
# </li>

# %%
# 종목명
list_items[1].find_all('a')[0].text
# Out:
# '인탑스'

# %%
# 리포트 제목
list_items[1].find_all('a')[1].text
# Out:
# '로봇 EMS 기대감'

# %%
list_items[1].find('div', {'class': 'line3'}).text.strip()
# Out:
# '적정가격\r\n\t \t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t30,000원'

# %%
#적정가격 <div class="line3">
list_items[1].find('div', {'class': 'line3'}).text.replace('적정가격', '').strip()
# Out:
# '30,000원'

# %%
# <div class="line3 color-red">
list_items[1].find_all('div', {'class': 'line3'})[1].text.strip()
# Out:
# '매수'

# %%
# <div class="line3">LS증권</div>
# <div class="line3">2024.10.28</div>

list_items[1].find_all('div', {'class': 'line3'})[2].text
# Out:
# 'LS증권'

# %%
list_items[1].find_all('div', {'class': 'line3'})[3].text
# Out:
# '2024.10.28'

# %% [markdown]
# # 페이지네이션을 고려한 반복문 생성

# %%
def parsing_li(li):
  # 종목명
  name = li.find_all('a')[0].text
  # 리포트 제목
  title =  li.find_all('a')[1].text
  #적정가격 <div class="line3">
  price = list_items[1].find('div', {'class': 'line3'}).text.replace('적정가격', '').strip()
  # <div class="line3 color-red">
  sell = li.find_all('div', {'class': 'line3'})[1].text.strip()
  # <div class="line3">LS증권</div>
  # <div class="line3">2024.10.28</div>
  stock_company = li.find_all('div', {'class': 'line3'})[2].text
  date = li.find_all('div', {'class': 'line3'})[3].text
